# %%
# !pip install opendatasets

# %%
import opendatasets as od
import pandas as pd
import numpy as np

# %%
od.download('https://www.kaggle.com/datasets/erdemtaha/cancer-data')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/erdemtaha/cancer-data
# ...
# 100%|██████████| 48.6k/48.6k [00:00<00:00, 66.4MB/s]

# %%
df=pd.read_csv('/content/cancer-data/Cancer_Data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df['diagnosis']=df['diagnosis'].map({'M':1,'B':0})

# %%
df=df.drop(columns=['id','Unnamed: 32'])

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# ...

# %%
x=df.drop(columns=['diagnosis'])
y=df['diagnosis']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-1.44075296, -0.43531947, -1.36208497, ...,  0.9320124 ,
#          2.09724217,  1.88645014],
#        [ 1.97409619,  1.73302577,  2.09167167, ...,  2.6989469 ,
#          1.89116053,  2.49783848],
#        [-1.39998202, -1.24962228, -1.34520926, ..., -0.97023893,
#          0.59760192,  0.0578942 ],
#        ...,
#        [ 0.04880192, -0.55500086, -0.06512547, ..., -1.23903365,
#         -0.70863864, -1.27145475],
#        [-0.03896885,  0.10207345, -0.03137406, ...,  1.05001236,
#          0.43432185,  1.21336207],
#        [-0.54860557,  0.31327591, -0.60350155, ..., -0.61102866,
#         -0.3345212 , -0.84628745]])

# %% [markdown]
# # converting numpy array to tensors

# %%
import torch

# %%
x_train_tensor=torch.from_numpy(x_train)
x_test_tensor=torch.from_numpy(x_test)

y_train_tensor=torch.from_numpy(y_train.values)
y_test_tensor=torch.from_numpy(y_test.values)

# %%
x_train_tensor.shape
# Out:
# torch.Size([455, 30])

# %%
y_train_tensor.shape
# Out:
# torch.Size([455])

# %% [markdown]
# # ***Defining model***

# %%
import torch

class MyNN:
    def __init__(self, x):
        self.weights = torch.rand(x.shape[1], 1, dtype=torch.float64, requires_grad=True)
        self.bias = torch.zeros(1, dtype=torch.float64, requires_grad=True)

    def feedForward(self, x):
        z = torch.matmul(x, self.weights) + self.bias
        y_pred = torch.sigmoid(z)
        return y_pred

    def loss_func(self, y_pred, y):
        eps = 1e-7  # Avoid log(0)
        y_pred = torch.clamp(y_pred, eps, 1 - eps) # to keep prediction in a safe range


        loss = -(y * torch.log(y_pred) + (1 - y) * torch.log(1 - y_pred)).mean()
        return loss

# %%
# Initializing parameters
learning_rate = 0.1
epochs = 50

# Training pipeline
model = MyNN(x_train_tensor)

for epoch in range(epochs):
    y_pred = model.feedForward(x_train_tensor)  # forward pass

    loss = model.loss_func(y_pred, y_train_tensor)  # compute loss

    loss.backward()  #  backward pass

    with torch.no_grad():  # disable gradient tracking during update
        # Gradient descent step
        model.weights -= learning_rate * model.weights.grad
        model.bias -= learning_rate * model.bias.grad

    # Zero gradients for next epoch
    model.weights.grad.zero_()
    model.bias.grad.zero_()

    print(f'Epoch: {epoch + 1}, Loss: {loss.item()}')
# Out:
# Epoch: 1, Loss: 3.8150988617707453
# Epoch: 2, Loss: 3.690910397118232
# Epoch: 3, Loss: 3.5640843998952865
# Epoch: 4, Loss: 3.430426714536542
# Epoch: 5, Loss: 3.293499735945138
# Epoch: 6, Loss: 3.1512181368577474
# Epoch: 7, Loss: 3.0068099946896405
# Epoch: 8, Loss: 2.8609176551217534
# Epoch: 9, Loss: 2.7097088589557257
# Epoch: 10, Loss: 2.5525990448797655
# Epoch: 11, Loss: 2.3860529109938113
# Epoch: 12, Loss: 2.2169906247752795
# Epoch: 13, Loss: 2.050019609778183
# Epoch: 14, Loss: 1.8859467830545662
# Epoch: 15, Loss: 1.7269925201281862
# Epoch: 16, Loss: 1.5775186305141307
# Epoch: 17, Loss: 1.43658038991014
# Epoch: 18, Loss: 1.3091641750140064
# Epoch: 19, Loss: 1.1926233136695108
# Epoch: 20, Loss: 1.089863083800028
# Epoch: 21, Loss: 1.004900387143703
# Epoch: 22, Loss: 0.9370426569839155
# Epoch: 23, Loss: 0.8845939842944828
# Epoch: 24, Loss: 0.8451467820466303
# Epoch: 25, Loss: 0.8160031504659125
# Epoch: 26, Loss: 0.7945664390678142
# ...

# %%
# model evaluation
with torch.no_grad():
  y_pred = model.feedForward(x_test_tensor)
  y_pred = (y_pred > 0.7).float()
  accuracy = (y_pred == y_test_tensor).float().mean()
  print(f'Accuracy: {accuracy.item()}')
# Out:
# Accuracy: 0.6184980273246765
